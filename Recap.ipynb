# %% [markdown]
# # KNN Recommender

# %% [markdown]
# 👉 K-Nearest-Neighbors (KNN) models can be used to model and make predictions, but they can alternatively be utilized to find the closest points in a dataset.
#
# 👨🏻‍🏫 In this recap, we will use a KNN model to create a basic music recommender system.

# %%
import pandas as pd

url = 'https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/ML_spotify_data.csv'

# Using pandas, load the data from the provided URL
df = pd.read_csv(url)
df.head()
# Out:
#                                                name  ...    tempo
# 0              We're For The Dark - Remastered 2010  ...  117.674
# 1                       Sixty Years On - Piano Demo  ...  143.783
# 2                           Got to Find Another Way  ...   84.341
# 3  Feelin' Alright - Live At The Fillmore East/1970  ...  174.005
# 4                                  Caravan - Take 7  ...   78.716
#
# [5 rows x 12 columns]

# %% [markdown]
# 🎯 Let's find songs that are "similar" to Queen's mythical *Another One Bites the Dust*.

# %%
queen_song = df.iloc[4295:4296] # Another One Bites the Dust - Queen

queen_song
# Out:
#                                                   name  ...    tempo
# 4295  Another One Bites The Dust - Live at Wembley '86  ...  115.991
#
# [1 rows x 12 columns]

# %% [markdown]
# ## 1. Calculating the distances

# %% [markdown]
# 👇 First, train the KNN to have it learn the distances between each observation of the dataset.
# Since we are only concerned with the similarity of features between the songs, it doesn't matter which target the model is fitted on.

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler

# %%
model = KNeighborsRegressor(n_neighbors=7)

# %%
X = df.drop(columns=['name', 'artists'])
X.head()
# Out:
#    popularity  danceability  valence  ...  loudness  speechiness    tempo
# 0          22         0.678    0.559  ...   -12.696       0.0334  117.674
# 1          25         0.456    0.259  ...   -10.692       0.0280  143.783
# 2          21         0.433    0.833  ...    -9.803       0.0378   84.341
# 3          22         0.436    0.870  ...    -6.955       0.0610  174.005
# 4          23         0.669    0.564  ...   -13.095       0.0679   78.716
#
# [5 rows x 10 columns]

# %%
transformer = MinMaxScaler()
X_scaled = pd.DataFrame(transformer.fit_transform(X), columns= X.columns)
X_scaled.head()
# Out:
#    popularity  danceability   valence  ...  loudness  speechiness     tempo
# 0    0.255814      0.687627  0.561245  ...  0.774548     0.034901  0.524307
# 1    0.290698      0.462475  0.260040  ...  0.807362     0.029258  0.640639
# 2    0.244186      0.439148  0.836345  ...  0.821918     0.039498  0.375789
# 3    0.255814      0.442191  0.873494  ...  0.868551     0.063741  0.775296
# 4    0.267442      0.678499  0.566265  ...  0.768015     0.070951  0.350726
#
# [5 rows x 10 columns]

# %%
y = df['tempo']

# %%
model.fit(X_scaled,y)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %% [markdown]
# ## 2. Passing the new point

# %% [markdown]
# 👇 You can now pass a new point to the KNN model and find its closest point.

# %%
queen_song
# Out:
#                                                   name  ...    tempo
# 4295  Another One Bites The Dust - Live at Wembley '86  ...  115.991
#
# [1 rows x 12 columns]

# %%
X_new = queen_song.drop(columns=['name', 'artists'])

# %%
X_new_scaled = pd.DataFrame(transformer.transform(X_new), columns=X_new.columns)
X_new_scaled
# Out:
#    popularity  danceability   valence  ...  loudness  speechiness     tempo
# 0    0.337209      0.541582  0.114458  ...  0.899612     0.310345  0.516809
#
# [1 rows x 10 columns]

# %%
nearest_songs = model.kneighbors(X_new_scaled, n_neighbors=2)
nearest_songs
# Out:
# (array([[0.        , 0.35999219]]), array([[4295, 1164]]))

# %%
df.iloc[nearest_songs[1][0][1]]
# Out:
# name            Hi, Hi, Hi - Live / Remastered
# artists                              ['Wings']
# popularity                                  27
# danceability                             0.219
# valence                                  0.162
# energy                                   0.939
# explicit                                     0
# key                                          4
# liveness                                 0.993
# loudness                                -9.275
# speechiness                              0.226
# tempo                                  140.832
# Name: 1164, dtype: object

# %%
df.iloc[nearest_songs[1][0][0]]
# Out:
# name            Another One Bites The Dust - Live at Wembley '86
# artists                                                ['Queen']
# popularity                                                    29
# danceability                                               0.534
# valence                                                    0.114
# energy                                                     0.984
# explicit                                                       0
# key                                                            4
# liveness                                                   0.982
# loudness                                                  -5.058
# speechiness                                                0.297
# tempo                                                    115.991
# Name: 4295, dtype: object

# %% [markdown]
# ## 3. Making a playlist!

# %% [markdown]
# 👇 Make a playlist with 10 songs based on Queen's *Another One Bites the Dust*, sorted by increasing tempo.

# %%
queen_song

# %%
base_playlist = model.kneighbors(X_new_scaled, n_neighbors=10)
indexes = base_playlist[1][0]
indexes
# Out:
# array([4295, 1164, 1761, 8607,  704, 1211, 3307, 2233, 2705, 1614])

# %%
playlist = df.iloc[indexes]
playlist
# Out:
#                                                    name  ...    tempo
# 4295   Another One Bites The Dust - Live at Wembley '86  ...  115.991
# 1164                     Hi, Hi, Hi - Live / Remastered  ...  140.832
# 1761                                               Liar  ...  107.064
# 8607                                        Cheat Codes  ...  128.001
# 704   It Ain't Me, Babe - Live at LA Forum, Inglewoo...  ...  100.490
# 1211                               A Light In The Black  ...  109.414
# 3307                                          Graveyard  ...   98.128
# 2233                        YYZ - Live In Canada / 1980  ...  145.905
# 2705                        A Sort Of Homecoming - Live  ...  125.824
# 1614  Clock Strikes Ten - Live at Nippon Budokan, To...  ...  161.160
#
# [10 rows x 12 columns]

# %%
playlist.sort_values(by='tempo', ascending=True, inplace= True)
playlist
# Out:
# /var/folders/7t/j9_7cdrd5594tqknpkvcx2gr0000gn/T/ipykernel_5528/3932360585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   playlist.sort_values(by='tempo', ascending=True, inplace= True)
#                                                    name  ...    tempo
# 3307                                          Graveyard  ...   98.128
# 704   It Ain't Me, Babe - Live at LA Forum, Inglewoo...  ...  100.490
# 1761                                               Liar  ...  107.064
# 1211                               A Light In The Black  ...  109.414
# 4295   Another One Bites The Dust - Live at Wembley '86  ...  115.991
# 2705                        A Sort Of Homecoming - Live  ...  125.824
# 8607                                        Cheat Codes  ...  128.001
# 1164                     Hi, Hi, Hi - Live / Remastered  ...  140.832
# 2233                        YYZ - Live In Canada / 1980  ...  145.905
# 1614  Clock Strikes Ten - Live at Nippon Budokan, To...  ...  161.160
#
# [10 rows x 12 columns]
